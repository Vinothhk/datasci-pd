# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st

# %%
# %matplotlib inline
# %matplotlib widget

# %%
dataset = pd.read_csv('newDataset.csv')
dataset
# Out:
#              q1        q2       q3        q4        q5   q6       x        y  \
# 0      0.531240 -0.309220  0.46022 -0.000805  0.130020  0.0  0.2553  0.15000
# 1     -0.200530  0.480510 -0.14141 -0.001043 -0.057845  0.0  0.4920 -0.10000
# 2      0.696370 -0.060094  0.49841  0.000969  0.129490  0.0  0.2667  0.22300
# 3     -0.064687  0.435570 -0.45136 -0.001830 -0.129870  0.0  0.4850 -0.03140
# 4     -0.661740 -0.012239  0.31486 -0.000736  0.078707  0.0  0.2940 -0.22900
# ...         ...       ...      ...       ...       ...  ...     ...      ...
# 14995 -0.495410 -0.405220  0.63910  0.004220  0.184300  0.0  0.2370 -0.12800
# 14996 -0.076337  0.233490 -0.42374 -0.001417 -0.112710  0.0  0.4133 -0.03160
# 14997 -0.321160  0.525500 -0.54525 -0.001725 -0.154460  0.0  0.4810 -0.16000
# 14998 -0.036980  0.297850 -0.47265 -0.001736 -0.127480  0.0  0.4329 -0.01600
# 14999 -0.019280 -0.751430  0.86350  0.002807  0.156100  0.0  0.1930 -0.00369
#
#            z
# 0      0.551
# 1      0.475
# ...

# %%
tool_pos = dataset[['x','y','z']]
# print(tool_pos.iloc[1,2])
tool_pos
# Out:
#             x        y      z
# 0      0.2553  0.15000  0.551
# 1      0.4920 -0.10000  0.475
# 2      0.2667  0.22300  0.456
# 3      0.4850 -0.03140  0.620
# 4      0.2940 -0.22900  0.510
# ...       ...      ...    ...
# 14995  0.2370 -0.12800  0.507
# 14996  0.4133 -0.03160  0.700
# 14997  0.4810 -0.16000  0.612
# 14998  0.4329 -0.01600  0.691
# 14999  0.1930 -0.00369  0.504
#
# [15000 rows x 3 columns]

# %%
tool_x = dataset['x']
tool_y = dataset['y']
tool_z = dataset['z']
ax = plt.axes(projection='3d')
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(-1,1)
plt.scatter(tool_x,tool_y,tool_z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(st.mean(tool_x))
print(st.stdev(tool_x))
# Out:
# 0.344813946
# 0.10254201096479074

# %%
print(st.mean(tool_y))
print(st.stdev(tool_y))
# Out:
# -0.0006965914733333333
# 0.10561807512976426

# %%
print(st.mean(tool_z))
print(st.stdev(tool_z))
# Out:
# 0.5072938086666666
# 0.1123164759152378
